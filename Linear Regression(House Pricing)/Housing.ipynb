# %% [markdown]
# ## Housing Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

file_path = "housing_price_dataset.csv"

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "muhammadbinimran/housing-price-prediction-data",
  file_path,
)

print("First 5 records:", df.head(10))
# Out:
# /tmp/ipython-input-4250937326.py:9: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# First 5 records:    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065
# 5        2095         2          3       Suburb       2020  198208.803907
# 6        2724         2          1       Suburb       1993  343429.319110
# 7        2044         4          3        Rural       1957  184992.321268
# 8        2638         4          3        Urban       1959  377998.588152
# 9        1121         5          2        Urban       2004   95961.926014

# %%
df = pd.get_dummies(df, columns=["Neighborhood"], drop_first=True)

print(df.head())
# Out:
#    SquareFeet  Bedrooms  Bathrooms  YearBuilt          Price  \
# 0        2126         4          1       1969  215355.283618
# 1        2459         3          2       1980  195014.221626
# 2        1860         2          1       1970  306891.012076
# 3        2294         2          1       1996  206786.787153
# 4        2130         5          2       2001  272436.239065
#
#    Neighborhood_Suburb  Neighborhood_Urban
# 0                False               False
# 1                False               False
# 2                 True               False
# 3                False                True
# 4                 True               False

# %%
df = df.astype({col: int for col in df.select_dtypes('bool').columns})

print(df.head())
# Out:
#    SquareFeet  Bedrooms  Bathrooms  YearBuilt          Price  \
# 0        2126         4          1       1969  215355.283618
# 1        2459         3          2       1980  195014.221626
# 2        1860         2          1       1970  306891.012076
# 3        2294         2          1       1996  206786.787153
# 4        2130         5          2       2001  272436.239065
#
#    Neighborhood_Suburb  Neighborhood_Urban
# 0                    0                   0
# 1                    0                   0
# 2                    1                   0
# 3                    0                   1
# 4                    1                   0

# %%
x = df.drop("Price", axis=1)
y = df["Price"]
print(x)
print(y)
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt  Neighborhood_Suburb  \
# 0            2126         4          1       1969                    0
# 1            2459         3          2       1980                    0
# 2            1860         2          1       1970                    1
# 3            2294         2          1       1996                    0
# 4            2130         5          2       2001                    1
# ...           ...       ...        ...        ...                  ...
# 49995        1282         5          3       1975                    0
# 49996        2854         2          2       1988                    1
# 49997        2979         5          3       1962                    1
# 49998        2596         5          2       1984                    0
# 49999        1572         5          3       2011                    0
#
#        Neighborhood_Urban
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ...                   ...
# 49995                   0
# 49996                   0
# 49997                   0
# 49998                   0
# 49999                   0
#
# [50000 rows x 6 columns]
# 0        215355.283618
# 1        195014.221626
# 2        306891.012076
# 3        206786.787153
# 4        272436.239065
#              ...
# 49995    100080.865895
# 49996    374507.656727
# 49997    384110.555590
# 49998    380512.685957
# 49999    221618.583218
# Name: Price, Length: 50000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R² Score:", r2)
# Out:
# MSE: 2436249371.3072467
# RMSE: 49358.376911191546
# MAE: 39430.16533829791
# R² Score: 0.5755628630306235

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
